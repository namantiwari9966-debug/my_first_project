# %% [markdown]
# <a href="https://colab.research.google.com/github/namantiwari9966-debug/my_first_project/blob/main/plotly_and_dash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly dash
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 57.8 MB/s eta 0:00:00
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
from dash import Dash, dcc, html
print("all libraries import succesfully")
# Out:
# all libraries import succesfully
